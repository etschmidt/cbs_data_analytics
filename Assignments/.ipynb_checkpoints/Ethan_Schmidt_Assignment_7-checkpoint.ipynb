# %% [markdown]
# <h1>Citibike Network Assignment</h1>
# <li>The file, 201809-citibike-tripdata.csv, contains citibike trip data from January 2014 (a reasonable sized file!)
# <li>The data:<br>
# "tripduration","starttime","stoptime","start station id","start station name","start station latitude","start station longitude","end station id","end station name","end station latitude","end station longitude","bikeid","usertype","birth year","gender"
# <li>Each record in the data is a trip
# <li>The data is described at https://www.citibikenyc.com/system-data

# %% [markdown]
# <h1>STEP 1: Read the data into a dataframe</h1>
# <li>Convert station ids to str if necessary

# %%
import pandas as pd
import numpy as np
datafile = "2014-01 - Citi Bike trip data.csv"
df = pd.read_csv(datafile)

# %%
df.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           471  2014-01-01 00:00:06  2014-01-01 00:07:57              2009
# 1          1494  2014-01-01 00:00:38  2014-01-01 00:25:32               536
# 2           464  2014-01-01 00:03:59  2014-01-01 00:11:43               228
# 3           373  2014-01-01 00:05:15  2014-01-01 00:11:28               519
# 4           660  2014-01-01 00:05:18  2014-01-01 00:16:18                83
#
#               start station name  start station latitude  \
# 0       Catherine St & Monroe St               40.711174
# 1                1 Ave & E 30 St               40.741444
# 2                E 48 St & 3 Ave               40.754601
# 3              Pershing Square N               40.751884
# 4  Atlantic Ave & Fort Greene Pl               40.683826
#
#    start station longitude  end station id          end station name  \
# 0               -73.996826             263  Elizabeth St & Hester St
# 1               -73.975361             259   South St & Whitehall St
# 2               -73.971879            2022       E 59 St & Sutton Pl
# 3               -73.977702             526           E 33 St & 5 Ave
# 4               -73.976323             436  Hancock St & Bedford Ave
#
#    end station latitude  end station longitude  bikeid    usertype birth year  \
# 0             40.717290             -73.996375   16379  Subscriber       1986
# 1             40.701221             -74.012342   15611  Subscriber       1963
# 2             40.758491             -73.959206   16613  Subscriber       1991
# 3             40.747659             -73.984907   15938  Subscriber       1989
# 4             40.682166             -73.953990   19830  Subscriber       1990
#
#    gender
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %% [markdown]
# <h1>STEP 2: Basic cleaning</h1>
# <li>Remove data that have any nans in any row (none in this file but others do have nans)
# <li>and convert stationids to str

# %%
df.dropna(inplace = True)

df['start station id'] = df['start station id'].astype(str)
df['end station id'] = df['end station id'].astype(str)

# %% [markdown]
# <h1>STEP 3: Write a function that returns a graph given a citibike data frame</h1>
# <li>Your function should return two things:
# <ol>
# <li>a graph
# <li>a dictionary with station ids as the key and station name as the value
# </ol>
# <li>The graph should contain
# <ol>
# <li>nodes (station ids)
# <li>edges (station id, station id)
# <li>edge data
# <ol>
# <li>count: number of trips on the edge
# <li>time: average duration - pickup to dropoff - on that edge
# </ol>
# </ol>
# <li><b>Note:</b> the edge (x1,y1) is the same as (y1,x1) even though the start station ids and end station ids are flipped in the dataframe

# %%
import networkx as nx
G= nx.Graph()
row = df.iloc[0]
start = row['start station id']
start
# Out:
# '2009'

# %%
def get_citibike_graph(df):
    import networkx as nx
    G = nx.Graph()
    node_names = dict()
    edges = dict()
    
    for ind in df.index:
        row = df.loc[ind]
        start = row['start station id']
        end = row['end station id']
        
        node_names[start] = row['start station name']
        node_names[end] = row['end station name']
        
        start,end = max(start, end), min(start, end)
        
        time = row['tripduration']
        
        if edges.get((start,end)):
            cnt = edges[(start,end)][0]+1
            time = time + edges[(start,end)][1]           
            edges[(start,end)] = (cnt,time)
        else: 
            edges[(start,end)] = (1,time)
    
        G.add_edge(start,end,trips=edges[(start,end)][0],time=edges[(start,end)][1]/edges[(start,end)][0])
    
    return G,node_names

# %% [markdown]
# <h1>STEP 4: Create the following graphs using the function above</h1>
# <li>G: A graph of all the data in the dataframe
# <li>m_G: A graph containing only data from male riders
# <li>f_G: A graph containing only data from female riders
# <li>Note: for m_G and f_G you will need to extract data from the dataframe

# %%
G,nodes=get_citibike_graph(df)

# %% [markdown]
# <h1>plot the graph</h2>

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

pos=nx.spring_layout(G) # positions for all nodes

# nodes
nx.draw_networkx_nodes(G,pos,
                       node_color='r',
                       node_size=5,
                      alpha=0.8)

# edges
#nx.draw_networkx_edges(sub_graph,pos,width=1.0,alpha=0.5)
nx.draw_networkx_edges(G,pos,
                       edgelist=G.edges(),
                       width=1,alpha=0.5,edge_color='b')

node_name={}
for node in G.nodes():
    node_name[node]=str(node)

nx.draw_networkx_edge_labels(G,pos,font_size=10) # takes dictionary as argument
node_name={}
for node in G.nodes():
    node_name[node]=str(node)

nx.draw_networkx_labels(G,pos,node_name,font_size=9)

plt.axis('off')
plt.show() # display

# %%
nodes
# Out:
# {'2009': 'Catherine St & Monroe St',
#  '263': 'Elizabeth St & Hester St',
#  '536': '1 Ave & E 30 St',
#  '259': 'South St & Whitehall St',
#  '228': 'E 48 St & 3 Ave',
#  '2022': 'E 59 St & Sutton Pl',
#  '519': 'Pershing Square N',
#  '526': 'E 33 St & 5 Ave',
#  '83': 'Atlantic Ave & Fort Greene Pl',
#  '436': 'Hancock St & Bedford Ave',
#  '422': 'W 59 St & 10 Ave',
#  '516': 'E 47 St & 1 Ave',
#  '167': 'E 39 St & 3 Ave',
#  '380': 'W 4 St & 7 Ave S',
#  '435': 'W 21 St & 6 Ave',
#  '296': 'Division St & Bowery',
#  '306': 'Cliff St & Fulton St',
#  '540': 'Lexington Ave & E 26 St',
#  '447': '8 Ave & W 52 St',
#  '251': 'Mott St & Prince St',
#  '153': 'E 40 St & 5 Ave',
#  '290': '2 Ave & E 58 St',
#  '151': 'Cleveland Pl & Spring St',
#  '410': 'Suffolk St & Stanton St',
#  '450': 'W 49 St & 8 Ave',
#  '505': '6 Ave & W 33 St',
#  '331': 'Pike St & Monroe St',
#  '195': 'Liberty St & Broadway',
#  '386': 'Centre St & Worth St',
#  '502': 'Henry St & Grand St',
#  '411': 'E 6 St & Avenue D',
#  '528': '2 Ave & E 31 St',
#  '518': 'E 39 St & 2 Ave',
#  '467': 'Dean St & 4 Ave',
#  '270': 'Adelphi St & Myrtle Ave',
#  '285': 'Broadway & E 14 St',
#  '382': 'University Pl & E 14 St',
#  '401': 'Allen St & Rivington St',
#  '488': 'W 39 St & 9 Ave',
#  '342': 'Columbia St & Rivington St',
#  '404': '9 Ave & W 14 St',
#  '507': 'E 25 St & 2 Ave',
#  '150': 'E 2 St & Avenue C',
#  '116': 'W 17 St & 8 Ave',
#  '537': 'Lexington Ave & E 24 St',
#  '448': 'W 37 St & 10 Ave',
#  '533': 'Broadway & W 39 St',
#  '525': 'W 34 St & 11 Ave',
#  '444': 'Broadway & W 24 St',
#  '236': 'St Marks Pl & 2 Ave',
#  '383': 'Greenwich Ave & Charles St',
#  '445': 'E 10 St & Avenue A',
#  '335': 'Washington Pl & Broadway',
#  '458': '11 Ave & W 27 St',
#  '3002': 'South End Ave & Liberty St',
#  '127': 'Barrow St & Hudson St',
#  '2006': 'Central Park S & 6 Ave',
#  '497': 'E 17 St & Broadway',
#  '390': 'Duffield St & Willoughby St',
#  '482': 'W 15 St & 7 Ave',
#  '509': '9 Ave & W 22 St',
#  '352': 'W 56 St & 6 Ave',
#  '128': 'MacDougal St & Prince St',
#  '545': 'E 23 St & 1 Ave',
#  '486': 'Broadway & W 29 St',
#  '168': 'W 18 St & 6 Ave',
#  '274': 'Lafayette Ave & Fort Greene Pl',
#  '244': 'Willoughby Ave & Hall St',
#  '258': 'DeKalb Ave & Vanderbilt Ave',
#  '302': 'Avenue D & E 3 St',
#  '317': 'E 6 St & Avenue B',
#  '428': 'E 3 St & 1 Ave',
#  '146': 'Hudson St & Reade St',
#  '334': 'W 20 St & 7 Ave',
#  '439': 'E 4 St & 2 Ave',
#  '402': 'Broadway & E 22 St',
#  '403': 'E 2 St & 2 Ave',
#  '354': 'Emerson Pl & Myrtle Ave',
#  '278': 'Concord St & Bridge St',
#  '366': 'Clinton Ave & Myrtle Ave',
#  '218': 'Gallatin Pl & Livingston St',
#  '418': 'Front St & Gold St',
#  '160': 'E 37 St & Lexington Ave',
#  '326': 'E 11 St & 1 Ave',
#  '521': '8 Ave & W 31 St',
#  '79': 'Franklin St & W Broadway',
#  '363': 'West Thames St',
#  '360': 'William St & Pine St',
#  '532': 'S 5 Pl & S 4 St',
#  '517': 'Pershing Square S',
#  '319': 'Park Pl & Church St',
#  '473': 'Rivington St & Chrystie St',
#  '529': 'W 42 St & 8 Ave',
#  '229': 'Great Jones St',
#  '433': 'E 13 St & Avenue A',
#  '350': 'Clinton St & Grand St',
#  '301': 'E 2 St & Avenue B',
#  '399': 'Lafayette Ave & St James Pl',
#  '365': 'Fulton St & Grand Ave',
#  '499': 'Broadway & W 60 St',
#  '515': 'W 43 St & 10 Ave',
#  '257': 'Lispenard St & Broadway',
#  '495': 'W 47 St & 10 Ave',
#  '307': 'Canal St & Rutgers St',
#  '320': 'Church St & Leonard St',
#  '479': '9 Ave & W 45 St',
#  '293': 'Lafayette St & E 8 St',
#  '323': 'Lawrence St & Willoughby St',
#  '271': 'Ashland Pl & Hanson Pl',
#  '396': 'Lefferts Pl & Franklin Ave',
#  '470': 'W 20 St & 8 Ave',
#  '524': 'W 43 St & 6 Ave',
#  '237': 'E 11 St & 2 Ave',
#  '284': 'Greenwich Ave & 8 Ave',
#  '512': 'W 29 St & 9 Ave',
#  '2012': 'E 27 St & 1 Ave',
#  '514': '12 Ave & W 40 St',
#  '250': 'Lafayette St & Jersey St',
#  '348': 'W Broadway & Spring St',
#  '161': 'LaGuardia Pl & W 3 St',
#  '358': 'Christopher St & Greenwich St',
#  '496': 'E 16 St & 5 Ave',
#  '312': 'Allen St & E Houston St',
#  '504': '1 Ave & E 15 St',
#  '511': 'E 14 St & Avenue B',
#  '347': 'W Houston St & Hudson St',
#  '72': 'W 52 St & 11 Ave',
#  '373': 'Willoughby Ave & Walworth St',
#  '2021': 'W 45 St & 8 Ave',
#  '330': 'Reade St & Broadway',
#  '531': 'Forsyth St & Broome St',
#  '449': 'W 52 St & 9 Ave',
#  '225': 'W 14 St & The High Line',
#  '369': 'Washington Pl & 6 Ave',
#  '385': 'E 55 St & 2 Ave',
#  '267': 'Broadway & W 36 St',
#  '490': '8 Ave & W 33 St',
#  '427': 'State St',
#  '351': 'Front St & Maiden Ln',
#  '459': 'W 20 St & 11 Ave',
#  '291': 'Madison St & Montgomery St',
#  '375': 'Mercer St & Bleecker St',
#  '82': 'St James Pl & Pearl St',
#  '238': 'Bank St & Washington St',
#  '325': 'E 19 St & 3 Ave',
#  '120': 'Lexington Ave & Classon Ave',
#  '313': 'Washington Ave & Park Ave',
#  '364': 'Lafayette Ave & Classon Ave',
#  '242': 'Flushing Ave & Carlton Ave',
#  '2010': 'Grand St & Greene St',
#  '397': 'Fulton St & Clermont Ave',
#  '407': 'Henry St & Poplar St',
#  '455': '1 Ave & E 44 St',
#  '322': 'Clinton St & Tillary St',
#  '414': 'Pearl St & Anchorage Pl',
#  '346': 'Bank St & Hudson St',
#  '494': 'W 26 St & 8 Ave',
#  '432': 'E 7 St & Avenue A',
#  '393': 'E 5 St & Avenue C',
#  '446': 'W 24 St & 7 Ave',
#  '462': 'W 22 St & 10 Ave',
#  '489': '10 Ave & W 28 St',
#  '281': 'Grand Army Plaza & Central Park S',
#  '461': 'E 20 St & 2 Ave',
#  '398': 'Atlantic Ave & Furman St',
#  '513': 'W 56 St & 10 Ave',
#  '174': 'E 25 St & 1 Ave',
#  '268': 'Howard St & Centre St',
#  '476': 'E 31 St & 3 Ave',
#  '453': 'W 22 St & 8 Ave',
#  '280': 'E 10 St & 5 Ave',
#  '368': 'Carmine St & 6 Ave',
#  '416': 'Cumberland St & Lafayette Ave',
#  '441': 'E 52 St & 2 Ave',
#  '297': 'E 15 St & 3 Ave',
#  '394': 'E 9 St & Avenue C',
#  '300': 'Shevchenko Pl & E 6 St',
#  '254': 'W 11 St & 6 Ave',
#  '311': 'Norfolk St & Broome St',
#  '336': 'Sullivan St & Washington Sq',
#  '417': 'Barclay St & Church St',
#  '464': 'E 56 St & 3 Ave',
#  '440': 'E 45 St & 3 Ave',
#  '143': 'Clinton St & Joralemon St',
#  '264': 'Maiden Ln & Pearl St',
#  '260': 'Broad St & Bridge St',
#  '412': 'Forsyth St & Canal St',
#  '498': 'Broadway & W 32 St',
#  '164': 'E 47 St & 2 Ave',
#  '485': 'W 37 St & 5 Ave',
#  '294': 'Washington Square E',
#  '480': 'W 53 St & 10 Ave',
#  '520': 'W 52 St & 5 Ave',
#  '147': 'Greenwich St & Warren St',
#  '463': '9 Ave & W 16 St',
#  '276': 'Duane St & Greenwich St',
#  '265': 'Stanton St & Chrystie St',
#  '295': 'Pike St & E Broadway',
#  '503': 'E 20 St & Park Ave',
#  '266': 'Avenue D & E 8 St',
#  '355': 'Bayard St & Baxter St',
#  '442': 'W 27 St & 7 Ave',
#  '339': 'Avenue D & E 12 St',
#  '483': 'E 12 St & 3 Ave',
#  '379': 'W 31 St & 7 Ave',
#  '420': 'Clermont Ave & Lafayette Ave',
#  '344': 'Monroe St & Bedford Ave',
#  '388': 'W 26 St & 10 Ave',
#  '137': 'E 56 St & Madison Ave',
#  '282': 'Kent Ave & S 11 St',
#  '405': 'Washington St & Gansevoort St',
#  '212': 'W 16 St & The High Line',
#  '223': 'W 13 St & 7 Ave',
#  '472': 'E 32 St & Park Ave',
#  '356': 'Bialystoker Pl & Delancey St',
#  '253': 'W 13 St & 5 Ave',
#  '345': 'W 13 St & 6 Ave',
#  '2004': '6 Ave & Broome St',
#  '474': '5 Ave & E 29 St',
#  '252': 'MacDougal St & Washington Sq',
#  '478': '11 Ave & W 41 St',
#  '224': 'Spruce St & Nassau St',
#  '475': 'E 16 St & Irving Pl',
#  '527': 'E 33 St & 1 Ave',
#  '239': 'Willoughby St & Fleet St',
#  '324': 'DeKalb Ave & Hudson Ave',
#  '377': '6 Ave & Canal St',
#  '249': 'Harrison St & Hudson St',
#  '466': 'W 25 St & 6 Ave',
#  '2002': 'Wythe Ave & Metropolitan Ave',
#  '157': 'Henry St & Atlantic Ave',
#  '353': 'S Portland Ave & Hanson Pl',
#  '310': 'State St & Smith St',
#  '492': 'W 33 St & 7 Ave',
#  '434': '9 Ave & W 18 St',
#  '469': 'Broadway & W 53 St',
#  '152': 'Warren St & Church St',
#  '304': 'Broadway & Battery Pl',
#  '454': 'E 51 St & 1 Ave',
#  '426': 'West St & Chambers St',
#  '261': 'Johnson St & Gold St',
#  '119': 'Park Ave & St Edwards St',
#  '241': 'DeKalb Ave & S Portland Ave',
#  '2003': '1 Ave & E 18 St',
#  '430': 'York St & Jay St',
#  '217': 'Old Fulton St',
#  '318': 'E 43 St & Vanderbilt Ave',
#  '2023': 'E 55 St & Lexington Ave',
#  '546': 'E 30 St & Park Ave S',
#  '247': 'Perry St & Bleecker St',
#  '539': 'Metropolitan Ave & Bedford Ave',
#  '395': 'Bond St & Schermerhorn St',
#  '487': 'E 20 St & FDR Drive',
#  '2000': 'Front St & Washington St',
#  '438': 'St Marks Pl & 1 Ave',
#  '384': 'Fulton St & Waverly Ave',
#  '361': 'Allen St & Hester St',
#  '376': 'John St & William St',
#  '329': 'Greenwich St & N Moore St',
#  '357': 'E 11 St & Broadway',
#  '508': 'W 46 St & 11 Ave',
#  '409': 'DeKalb Ave & Skillman St',
#  '332': 'Cherry St',
#  '367': 'E 53 St & Lexington Ave',
#  '391': 'Clark St & Henry St',
#  '423': 'W 54 St & 9 Ave',
#  '471': 'Grand St & Havemeyer St',
#  '389': 'Broadway & Berry St',
#  '343': 'Clinton Ave & Flushing Ave',
#  '328': 'Watts St & Greenwich St',
#  '437': 'Macon St & Nostrand Ave',
#  '144': 'Nassau St & Navy St',
#  '262': 'Washington Park',
#  '341': 'Stanton St & Mangin St',
#  '314': 'Montague St & Clinton St',
#  '243': 'Fulton St & Rockwell Pl',
#  '460': 'S 4 St & Wythe Ave',
#  '538': 'W 49 St & 5 Ave',
#  '400': 'Pitt St & Stanton St',
#  '408': 'Market St & Cherry St',
#  '421': 'Clermont Ave & Park Ave',
#  '501': 'FDR Drive & E 35 St',
#  '534': 'Water - Whitehall Plaza',
#  '308': 'St James Pl & Oliver St',
#  '484': 'W 44 St & 5 Ave',
#  '327': 'Vesey Pl & River Terrace',
#  '415': 'Pearl St & Hanover Square',
#  '309': 'Murray St & West St',
#  '406': 'Hicks St & Montague St',
#  '232': 'Cadman Plaza E & Tillary St',
#  '2017': 'E 43 St & 2 Ave',
#  '233': 'Joralemon St & Adams St',
#  '279': 'Sands St & Gold St',
#  '245': 'Myrtle Ave & St Edwards St',
#  '305': 'E 58 St & 3 Ave',
#  '2008': 'Little West St & 1 Pl',
#  '340': 'Madison St & Clinton St',
#  '522': 'E 51 St & Lexington Ave',
#  '216': 'Columbia Heights & Cranberry St',
#  '248': 'Laight St & Hudson St',
#  '316': 'Fulton St & William St',
#  '275': 'Washington Ave & Greene Ave',
#  '372': 'Franklin Ave & Myrtle Ave',
#  '2001': '7 Ave & Farragut St',
#  '298': '3 Ave & Schermerhorn St',
#  '523': 'W 38 St & 8 Ave',
#  '349': 'Rivington St & Ridge St',
#  '303': 'Mercer St & Spring St',
#  '456': 'E 53 St & Madison Ave',
#  '315': 'South St & Gouverneur Ln',
#  '392': 'Jay St & Tech Pl',
#  '481': 'S 3 St & Bedford Ave',
#  '510': 'W 51 St & 6 Ave',
#  '457': 'Broadway & W 58 St',
#  '362': 'Broadway & W 37 St',
#  '477': 'W 41 St & 8 Ave',
#  '465': 'Broadway & W 41 St',
#  '359': 'E 47 St & Park Ave',
#  '337': 'Old Slip & Front St',
#  '493': 'W 45 St & 6 Ave',
#  '289': 'Monroe St & Classon Ave',
#  '387': 'Centre St & Chambers St',
#  '443': 'Bedford Ave & S 9th St',
#  '2005': 'Railroad Ave & Kay Ave',
#  '431': 'Hanover Pl & Livingston St',
#  '500': 'Broadway & W 51 St',
#  '173': 'Broadway & W 49 St',
#  '468': 'Broadway & W 55 St',
#  '419': 'Carlton Ave & Park Ave'}

# %%
m_df = df[df['gender'] == 1]
m_G=get_citibike_graph(m_df)[0]

# %%
f_df = df[df['gender'] == 2]
f_G=get_citibike_graph(f_df)[0]

# %% [markdown]
# <h1>STEP 5: Answer the following questions for each of the graphs</h1>
# <ol>
# <li>Which station (name) is the best connected (max degree)?
# <li>Travel between which pair of stations is the longest in terms of average duration between bike pickups and dropoffs. Report both the two stations as well as the time in minutes
# <li>Which edge is associated with the most number of trips?
# <li>Which station is the most central?
# <li>Which node is a bottleneck node?

# %% [markdown]
# Which station (name) has the greatest number of connections (max degree)?

# %%
n = list(G.degree)
sorted(n, key=lambda x: x[1], reverse=True)[0]
# Out:
# ('323', 299)

# %% [markdown]
# Which edge is associated with the most number of trips?

# %%
e = G.edges(data=True)

sorted(e, key=lambda x: x[2]['trips'], reverse=True)[0]
# Out:
# ('318', '477', {'trips': 378, 'time': 469.25925925925924})

# %% [markdown]
# <h2>Centrality</h2>
# One of the concerns that the citibike system has to deal with is ensuring that no station has empty slots (a bike should always be available) and that no station should have no empty slots (you should be able to return a bike). To do this, it needs to monitor the movement of bikes through the system, ideally using a directed graph. Though our graph is not directed, we can look at some network characteristics that will help us answer these questions. Note that the "trips" feature in edge data captures flows.
# <li>Which node is a possible bottleneck node in terms of bike flows?
# <li>Which node is the "nearest" to all other nodes (irrespective of flows)
# <li>Which node is the "nearest" to all other nodes (in terms of distance = time)
# <li>Which nodes are peripheral (most likely to be underserved)

# %%
from networkx.algorithms import closeness_centrality
from networkx.algorithms import communicability

# %%
c_c = closeness_centrality(G)

# %%
from collections import OrderedDict
cc = OrderedDict(sorted(
                    c_c.items(),
                    key = lambda x: x[1],
                    reverse = True))
list(cc)[0] # most connected
# Out:
# '323'

# %%
from networkx.algorithms.distance_measures import center
center(G)
# Out:
# ['263',
#  '2009',
#  '536',
#  '259',
#  '228',
#  '2022',
#  '526',
#  '519',
#  '83',
#  '436',
#  '422',
#  '516',
#  '167',
#  '435',
#  '380',
#  '306',
#  '296',
#  '540',
#  '447',
#  '251',
#  '290',
#  '153',
#  '410',
#  '151',
#  '505',
#  '450',
#  '331',
#  '195',
#  '386',
#  '502',
#  '411',
#  '528',
#  '518',
#  '467',
#  '270',
#  '285',
#  '401',
#  '382',
#  '488',
#  '342',
#  '404',
#  '507',
#  '150',
#  '116',
#  '537',
#  '448',
#  '533',
#  '525',
#  '444',
#  '236',
#  '445',
#  '383',
#  '458',
#  '335',
#  '3002',
#  '127',
#  '497',
#  '2006',
#  '390',
#  '482',
#  '509',
#  '352',
#  '545',
#  '128',
#  '486',
#  '168',
#  '274',
#  '258',
#  '244',
#  '317',
#  '302',
#  '428',
#  '146',
#  '439',
#  '334',
#  '402',
#  '403',
#  '354',
#  '278',
#  '366',
#  '418',
#  '218',
#  '160',
#  '326',
#  '79',
#  '521',
#  '363',
#  '360',
#  '532',
#  '517',
#  '473',
#  '319',
#  '529',
#  '229',
#  '433',
#  '350',
#  '301',
#  '399',
#  '365',
#  '515',
#  '499',
#  '495',
#  '257',
#  '307',
#  '320',
#  '479',
#  '293',
#  '323',
#  '396',
#  '271',
#  '470',
#  '524',
#  '237',
#  '512',
#  '284',
#  '2012',
#  '514',
#  '250',
#  '348',
#  '161',
#  '496',
#  '358',
#  '312',
#  '504',
#  '511',
#  '72',
#  '347',
#  '373',
#  '330',
#  '2021',
#  '531',
#  '449',
#  '369',
#  '225',
#  '385',
#  '490',
#  '267',
#  '427',
#  '351',
#  '459',
#  '375',
#  '291',
#  '82',
#  '238',
#  '325',
#  '313',
#  '120',
#  '364',
#  '242',
#  '2010',
#  '397',
#  '407',
#  '455',
#  '414',
#  '322',
#  '346',
#  '494',
#  '432',
#  '393',
#  '462',
#  '446',
#  '489',
#  '281',
#  '461',
#  '398',
#  '513',
#  '174',
#  '476',
#  '268',
#  '453',
#  '280',
#  '368',
#  '416',
#  '441',
#  '297',
#  '394',
#  '300',
#  '254',
#  '311',
#  '336',
#  '417',
#  '464',
#  '440',
#  '143',
#  '264',
#  '412',
#  '260',
#  '498',
#  '164',
#  '485',
#  '294',
#  '480',
#  '520',
#  '147',
#  '463',
#  '276',
#  '265',
#  '295',
#  '503',
#  '266',
#  '355',
#  '442',
#  '483',
#  '379',
#  '420',
#  '344',
#  '388',
#  '137',
#  '282',
#  '405',
#  '223',
#  '212',
#  '472',
#  '356',
#  '253',
#  '345',
#  '2004',
#  '474',
#  '252',
#  '478',
#  '224',
#  '475',
#  '527',
#  '239',
#  '324',
#  '377',
#  '249',
#  '466',
#  '2002',
#  '353',
#  '157',
#  '310',
#  '492',
#  '434',
#  '469',
#  '152',
#  '304',
#  '454',
#  '426',
#  '261',
#  '119',
#  '241',
#  '2003',
#  '430',
#  '217',
#  '318',
#  '2023',
#  '546',
#  '247',
#  '539',
#  '395',
#  '487',
#  '2000',
#  '438',
#  '384',
#  '361',
#  '376',
#  '329',
#  '357',
#  '508',
#  '409',
#  '332',
#  '367',
#  '391',
#  '471',
#  '389',
#  '343',
#  '328',
#  '437',
#  '144',
#  '262',
#  '341',
#  '314',
#  '243',
#  '460',
#  '538',
#  '400',
#  '408',
#  '421',
#  '501',
#  '534',
#  '308',
#  '484',
#  '327',
#  '415',
#  '309',
#  '406',
#  '232',
#  '2017',
#  '233',
#  '279',
#  '245',
#  '305',
#  '2008',
#  '340',
#  '522',
#  '216',
#  '248',
#  '316',
#  '275',
#  '372',
#  '2001',
#  '298',
#  '523',
#  '349',
#  '303',
#  '315',
#  '392',
#  '481',
#  '510',
#  '457',
#  '362',
#  '477',
#  '465',
#  '359',
#  '337',
#  '493',
#  '289',
#  '387',
#  '443',
#  '431',
#  '500',
#  '173',
#  '468']

# %%
nx.betweenness_centrality(G, weight='time')
