# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("https://raw.githubusercontent.com/fivethirtyeight/data/master/college-majors/recent-grads.csv")

# %%
df
# Out:
#      Rank  Major_code                                          Major  \
# 0       1        2419                          PETROLEUM ENGINEERING
# 1       2        2416                 MINING AND MINERAL ENGINEERING
# 2       3        2415                      METALLURGICAL ENGINEERING
# 3       4        2417      NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4       5        2405                           CHEMICAL ENGINEERING
# 5       6        2418                            NUCLEAR ENGINEERING
# 6       7        6202                              ACTUARIAL SCIENCE
# 7       8        5001                     ASTRONOMY AND ASTROPHYSICS
# 8       9        2414                         MECHANICAL ENGINEERING
# 9      10        2408                         ELECTRICAL ENGINEERING
# 10     11        2407                           COMPUTER ENGINEERING
# 11     12        2401                          AEROSPACE ENGINEERING
# 12     13        2404                         BIOMEDICAL ENGINEERING
# ...

# %%
df.corr()
# Out:
#                           Rank  Major_code     Total       Men     Women  \
# Rank                  1.000000    0.108429  0.071137 -0.094780  0.174913
# Major_code            0.108429    1.000000  0.196784  0.179299  0.181459
# Total                 0.071137    0.196784  1.000000  0.878088  0.944764
# Men                  -0.094780    0.179299  0.878088  1.000000  0.672759
# Women                 0.174913    0.181459  0.944764  0.672759  1.000000
# ShareWomen            0.643781    0.259211  0.142999 -0.112014  0.297832
# Sample_size           0.008492    0.206580  0.945575  0.875176  0.862606
# Employed              0.070751    0.200925  0.996214  0.870605  0.944037
# Full_time             0.034725    0.199397  0.989339  0.893563  0.917681
# Part_time             0.193174    0.195184  0.950268  0.751592  0.954513
# Full_time_year_round  0.020418    0.205634  0.981112  0.892454  0.905720
# Unemployed            0.090078    0.223418  0.974768  0.869411  0.911694
# ...

# %%
interesting = ['Median', 'ShareWomen', 'Unemployment_rate']
df[interesting].corr()
# Out:
#                      Median  ShareWomen  Unemployment_rate
# Median             1.000000   -0.618690          -0.108833
# ShareWomen        -0.618690    1.000000           0.073205
# Unemployment_rate -0.108833    0.073205           1.000000

# %%
df['Median'].mean()
# Out:
# 40151.4450867052

# %%
df.loc[df['Major_category'] == 'Engineering' ]
# Out:
#     Rank  Major_code                                        Major    Total  \
# 0      1        2419                        PETROLEUM ENGINEERING   2339.0
# 1      2        2416               MINING AND MINERAL ENGINEERING    756.0
# 2      3        2415                    METALLURGICAL ENGINEERING    856.0
# 3      4        2417    NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4      5        2405                         CHEMICAL ENGINEERING  32260.0
# 5      6        2418                          NUCLEAR ENGINEERING   2573.0
# 8      9        2414                       MECHANICAL ENGINEERING  91227.0
# 9     10        2408                       ELECTRICAL ENGINEERING  81527.0
# 10    11        2407                         COMPUTER ENGINEERING  41542.0
# 11    12        2401                        AEROSPACE ENGINEERING  15058.0
# 12    13        2404                       BIOMEDICAL ENGINEERING  14955.0
# ...

# %%
df.sort_values("Total", ascending=False)
# Out:
#      Rank  Major_code                                              Major  \
# 145   146        5200                                         PSYCHOLOGY
# 76     77        6203             BUSINESS MANAGEMENT AND ADMINISTRATION
# 123   124        3600                                            BIOLOGY
# 57     58        6200                                   GENERAL BUSINESS
# 93     94        1901                                     COMMUNICATIONS
# 34     35        6107                                            NURSING
# 77     78        6206                   MARKETING AND MARKETING RESEARCH
# 40     41        6201                                         ACCOUNTING
# 137   138        3301                    ENGLISH LANGUAGE AND LITERATURE
# 78     79        5506                   POLITICAL SCIENCE AND GOVERNMENT
# 35     36        6207                                            FINANCE
# 138   139        2304                               ELEMENTARY EDUCATION
# ...

# %%
# should sort first if you want
df.drop_duplicates(subset='Major_category')
# Out:
#      Rank  Major_code                                     Major     Total  \
# 0       1        2419                     PETROLEUM ENGINEERING    2339.0
# 6       7        6202                         ACTUARIAL SCIENCE    3777.0
# 7       8        5001                ASTRONOMY AND ASTROPHYSICS    1792.0
# 19     20        3201                           COURT REPORTING    1148.0
# 20     21        2102                          COMPUTER SCIENCE  128319.0
# 21     22        1104                              FOOD SCIENCE       NaN
# 26     27        5601                     CONSTRUCTION SERVICES   18498.0
# 32     33        6099                   MISCELLANEOUS FINE ARTS    3340.0
# 34     35        6107                                   NURSING  209394.0
# 36     37        5501                                 ECONOMICS  139247.0
# 48     49        3607                              PHARMACOLOGY    1762.0
# 55     56        2303                 SCHOOL STUDENT COUNSELING     818.0
# ...
